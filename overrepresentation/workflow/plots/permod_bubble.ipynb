# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from cmcrameri import cm

# %%
## Import full enrichment results
data_dir = r"C:\Users\neil_\DellXPS_June2024\OneDrive\Desktop\New UHN\Precision Medicine\carotid_plaque\workflow\pathway_enrichment\\"
kegg_permod = pd.read_csv(data_dir+"permod_KEGG.csv")
go_permod = pd.read_csv(data_dir+"permod_GO.csv")

for df in [kegg_permod, go_permod]:
    df.drop(columns=["Unnamed: 0", "module"], inplace=True)
    df.rename(columns={"Term": "pathway",
                       "Adjusted P-value":"q-value",
                       "Fold_Enrichment":"fold_enrichment"},
    inplace=True)

# %%
## Import filtered lists (filtered by SR)
data_dir = r"C:\Users\neil_\DellXPS_June2024\OneDrive\Desktop\New UHN\Precision Medicine\carotid_plaque\data\filtered_lists\\"
kegg_top = pd.read_csv(data_dir+"permod_kegg_top.txt", sep="\t", header=None) # NP removed redundant pathways "Longevity regulating pathway - multiple species", "Apoptosis - multiple species"
kegg_ec =  pd.read_csv(data_dir+"permod_kegg_ec.txt", sep="\t", header=None)

go_top = pd.read_csv(data_dir+"permod_go_top.txt", sep="\t", header=None)
go_ec =  pd.read_csv(data_dir+"permod_go_ec.txt", sep="\t", header=None)

# %%
class Enrichment:
    def __init__(self, db, all_df, top_df, ec_df):
        self.database = db
        self.enrichment_df = all_df
        self.top_pathways = list(set(top_df[0]))
        self.endo_pathways = list(set(top_df[0]))

# %%
GO_permod = Enrichment("GO BP", go_permod, go_top, go_ec)
KEGG_permod = Enrichment("KEGG", kegg_permod, kegg_top, kegg_ec)

# %%
def subset_plot_df(plot_df, n=20):
    '''Include the top n (by fold enrichment) pathways for both cohorts in plot_df'''
    pathways_to_plot = set()
    for cohort in ["symptomatic", "asymptomatic"]:
        cohort_df = plot_df[plot_df["cohort"] == cohort]
        cohort_pthwys = cohort_df.sort_values(by="fold_enrichment", ascending=False).drop_duplicates(subset="pathway").head(n)["pathway"]
        pathways_to_plot.update(cohort_pthwys)

    # Filter plot_df to include top n pathways for either cohort
    symp_df = plot_df[plot_df["cohort"] == "symptomatic"].sort_values(by="fold_enrichment", ascending=False).drop_duplicates(subset="pathway")
    symp_df = symp_df[symp_df["pathway"].isin(pathways_to_plot)]

    asymp_df = plot_df[plot_df["cohort"] == "asymptomatic"].sort_values(by="fold_enrichment", ascending=False).drop_duplicates(subset="pathway")
    asymp_df = asymp_df[asymp_df["pathway"].isin(pathways_to_plot)]
    
    filtered_df = pd.concat([symp_df, asymp_df])

    return filtered_df

# %%
for Enr in [GO_permod, KEGG_permod]:
    full_df = Enr.enrichment_df
    top_pthwys = Enr.top_pathways
    # Only include pathways specified by SR
    Enr.prebubble_df = full_df[full_df["pathway"].isin(top_pthwys)]
    Enr.plot_df = subset_plot_df(Enr.prebubble_df)

# %%
### KEGG

# %%
from bioservices import *
import time

kg = KEGG()
kg.organism = "hsa" #specify human as organism 


res = kg.list("pathway", organism="hsa")
all_kegg = res.rstrip("\n").split("\n")
all_kegg = [x.rstrip("Homo sapiens (human)") for x in all_kegg]
all_kegg = [x.rstrip("-") for x in all_kegg]
all_kegg = [x.rstrip() for x in all_kegg]
#pathway_dict = {kegg_id: kegg_pthwy for kegg_id, kegg_pthwy in (pathway.split("\t") for pathway in pathways)}

# Initialize an empty dictionary
kegg_id_pthwy_dict = {}

# Iterate over each string in the pathways list
for pathway in all_kegg:
    # Split the string into KEGG ID and KEGG pathway
    kegg_id, kegg_pthwy = pathway.split("\t")
    # Add the KEGG ID and pathway to the dictionary
    kegg_id_pthwy_dict[kegg_pthwy] = kegg_id

# %%
# Check if all KEGG pathways we need to annotate have IDs
cp_kegg_list = list(KEGG_permod.plot_df["pathway"])
set(cp_kegg_list).issubset(kegg_id_pthwy_dict.keys())
# Out:
# False

# %%
[x for x in cp_kegg_list if x not in kegg_id_pthwy_dict.keys()]
# No hsa ID
# Out:
# ['Mitophagy']

# %%
kegg_id_pthwy_dict['Mitophagy'] = 'hsa04137' #Looked up on https://www.genome.jp/entry/pathway+hsa04137

# %%
def get_kegg_class(kegg_pthwy):
    kegg_id = kegg_id_pthwy_dict[kegg_pthwy]
    class_ = (kg.parse(kg.get(kegg_id))["CLASS"]).split("; ") #This will be a list

    class_0 = class_[0] # Take the first level class
    return class_0

KEGG_permod.plot_df["class"] = KEGG_permod.plot_df["pathway"].apply(get_kegg_class)

# %%
def encode_cohort(plot_df):
    encode_cohort_map = {"asymptomatic":0,
                         "symptomatic":1}
    encoded_df = plot_df.copy()
    encoded_df["cohort"] = encoded_df["cohort"].map(encode_cohort_map)
    encoded_df.rename(columns = {"cohort":"cohort_encoded"}, inplace=True)
    return encoded_df

KEGG_permod.plot_df = encode_cohort(KEGG_permod.plot_df)

# %%
def format_bubble_df(bubble_df_):
    '''Formats bubble_df by taking the columns needed for plot maker. Also adds rows for wrapping figure'''
    
    #new_df = bubble_df_[["pathway", "cohort_encoded", "q-value", "fold_enrichment"]].copy()
    
    wrap_row1 = pd.DataFrame([{'pathway': 'wrap', 'cohort_encoded': -0.5, 'q-value': 0.001, 'fold_enrichment': 1, 'class':'z'}])
    wrap_row2 = pd.DataFrame([{'pathway': 'wrap', 'cohort_encoded': 1.5, 'q-value': 0.001, 'fold_enrichment': 1, 'class':'z'}])
    
    wrap_rows = pd.concat([wrap_row1, wrap_row2])
    
    formatted_bubble_df = pd.concat([bubble_df_, wrap_rows], ignore_index=True).copy()
    formatted_bubble_df = formatted_bubble_df[["pathway", "cohort_encoded", "q-value", "fold_enrichment", "class"]]
    return formatted_bubble_df

KEGG_permod.plot_df = format_bubble_df(KEGG_permod.plot_df)
#KEGG_miRNA.plot_df = KEGG_miRNA.plot_df[["pathway", "cohort_encoded", "q-value", "fold_enrichment", "class"]]
KEGG_permod.plot_df
# Out:
#                                               pathway  cohort_encoded  \
# 
# 27   3.939781e-02        27.664935              Organismal Systems
# 28   4.257969e-02        26.947502              Organismal Systems
# 29   1.059623e-02        22.376050              Cellular Processes
# 30   3.201598e-87        19.861242  Genetic Information Processing
# 31   5.581295e-22        18.639250                      Metabolism
# 32   2.563641e-48        15.194501  Genetic Information Processing
# 33   1.738322e-33        13.743503  Genetic Information Processing
# 34   4.749696e-05        12.903600  Genetic Information Processing
# 35  1.376000e-110        12.521381  Genetic Information Processing
# 36   1.807726e-17        12.119356  Genetic Information Processing
# 37   1.165380e-29        11.854201  Genetic Information Processing
# 38   2.198450e-05        10.950778  Genetic Information Processing
# 39   4.631129e-02         9.442376                      Metabolism
# 40   3.493700e-08         9.252147  Genetic Information Processing
# 41   9.200868e-06         7.940804                      Metabolism
# 42   1.000000e-03         1.000000                               z
# 43   1.000000e-03         1.000000                               z

# %%
# Shorten class text for figure
KEGG_permod.plot_df.loc[KEGG_permod.plot_df["class"] == "Genetic Information Processing", "class"] = "Gene. Info. Processing"
KEGG_permod.plot_df.loc[KEGG_permod.plot_df["class"] == "Human Diseases", "class"] = "Diseases"
KEGG_permod.plot_df.loc[KEGG_permod.plot_df["class"] == "Cellular Processes", "class"] = "Cell Proc."
KEGG_permod.plot_df
# Out:
#                                               pathway  cohort_encoded  \
# 0   Phenylalanine, tyrosine and tryptophan biosynt...             1.0
# 1                 Complement and coagulation cascades             1.0
# 2                                Steroid biosynthesis             1.0
# 3                                 Caffeine metabolism             1.0
# 4                                      RNA polymerase             1.0
# 5                              Cholesterol metabolism             1.0
# 6                               p53 signaling pathway             1.0
# 7                                          Proteasome             1.0
# 8                                         Spliceosome             1.0
# 9                                   Phototransduction             1.0
# 10        Protein processing in endoplasmic reticulum             1.0
# 11                                   Circadian rhythm             1.0
# 12          SNARE interactions in vesicular transport             1.0
# 13  Glycosylphosphatidylinositol (GPI)-anchor bios...             1.0
# 14                         Autoimmune thyroid disease             1.0
# 15                          Citrate cycle (TCA cycle)             1.0
# 16                                    DNA replication             1.0
# 17                                    Mismatch repair             1.0
# 18                             Fanconi anemia pathway             1.0
# 19                                           Ribosome             1.0
# 20                               Base excision repair             1.0
# 21                              Propanoate metabolism             1.0
# 22                               Steroid biosynthesis             0.0
# 23    Arrhythmogenic right ventricular cardiomyopathy             0.0
# 24                Antigen processing and presentation             0.0
# 25                              p53 signaling pathway             0.0
# 26                    Fc epsilon RI signaling pathway             0.0
# 27                                  Phototransduction             0.0
# 28                                   Circadian rhythm             0.0
# 29                                          Mitophagy             0.0
# 30                                           Ribosome             0.0
# 31                          Citrate cycle (TCA cycle)             0.0
# 32                                         Proteasome             0.0
# 33          SNARE interactions in vesicular transport             0.0
# 34                                    DNA replication             0.0
# 35                                        Spliceosome             0.0
# 36                                    Mismatch repair             0.0
# 37                             Fanconi anemia pathway             0.0
# 38                                     RNA polymerase             0.0
# 39             Phosphonate and phosphinate metabolism             0.0
# 40                               Base excision repair             0.0
# 41                              Propanoate metabolism             0.0
# 42                                               wrap            -0.5
# 43                                               wrap             1.5
#
#           q-value  fold_enrichment                   class
# 0    2.884242e-02       443.791667              Metabolism
# 1    1.230231e-11       250.611765      Organismal Systems
# 2    2.394276e-02       177.516667              Metabolism
# 3    2.677471e-03        83.537255              Metabolism
# 4    1.713876e-55        66.155280  Gene. Info. Processing
# 5    5.896419e-05        53.255000      Organismal Systems
# 6    1.273469e-02        53.056040              Cell Proc.
# 7    7.108092e-65        36.713200  Gene. Info. Processing
# 8   4.488386e-149        32.840583  Gene. Info. Processing
# 9    3.939781e-02        27.664935      Organismal Systems
# 10   1.915384e-09        27.345315  Gene. Info. Processing
# 11   4.257969e-02        26.947502      Organismal Systems
# 12   2.725790e-42        26.516669  Gene. Info. Processing
# 13   8.171434e-05        20.397702              Metabolism
# 14   2.369811e-16        19.139263                Diseases
# 15   1.700284e-21        17.751667              Metabolism
# 16   4.749696e-05        12.903600  Gene. Info. Processing
# 17   1.807726e-17        12.119356  Gene. Info. Processing
# 18   1.165380e-29        11.854201  Gene. Info. Processing
# 19   5.244762e-21        11.513792  Gene. Info. Processing
# 20   3.493700e-08         9.252147  Gene. Info. Processing
# 21   9.200868e-06         7.940804              Metabolism
# 22   2.394276e-02       177.516667              Metabolism
# 23   4.289282e-02        69.162338                Diseases
# 24   2.254221e-02        60.689459      Organismal Systems
# 25   1.273469e-02        53.056040              Cell Proc.
# 26   3.756794e-02        36.854671      Organismal Systems
# 27   3.939781e-02        27.664935      Organismal Systems
# 28   4.257969e-02        26.947502      Organismal Systems
# 29   1.059623e-02        22.376050              Cell Proc.
# 30   3.201598e-87        19.861242  Gene. Info. Processing
# 31   5.581295e-22        18.639250              Metabolism
# 32   2.563641e-48        15.194501  Gene. Info. Processing
# 33   1.738322e-33        13.743503  Gene. Info. Processing
# 34   4.749696e-05        12.903600  Gene. Info. Processing
# 35  1.376000e-110        12.521381  Gene. Info. Processing
# 36   1.807726e-17        12.119356  Gene. Info. Processing
# 37   1.165380e-29        11.854201  Gene. Info. Processing
# 38   2.198450e-05        10.950778  Gene. Info. Processing
# 39   4.631129e-02         9.442376              Metabolism
# 40   3.493700e-08         9.252147  Gene. Info. Processing
# 41   9.200868e-06         7.940804              Metabolism
# 42   1.000000e-03         1.000000                       z
# 43   1.000000e-03         1.000000                       z

# %%
KEGG_permod.plot_df.to_csv('permod_kegg_bubble.txt', sep ='\t',index=False)

# %% [markdown]
# ## GO

# %%
GO_permod.plot_df
# Out:
#                                                pathway       q-value  \
# 122  Regulation Of Hepatocyte Proliferation (GO:200...  2.846111e-02
# 116         C-terminal Protein Lipidation (GO:0006501)  2.339896e-02
# 120  Regulation Of Endothelial Cell Differentiation...  4.575242e-06
# 109    Sphingomyelin Biosynthetic Process (GO:0006686)  1.556115e-03
# 84   Complement Activation, Lectin Pathway (GO:0001...  3.212822e-08
# 101         Protein Retention In ER Lumen (GO:0006621)  2.776245e-03
# 11         40.575238   symptomatic
# 107        40.041353   symptomatic
# 89         39.816822   symptomatic
# 92         38.381982   symptomatic
# 95         36.043993   symptomatic
# 91         27.345315   symptomatic
# 9          25.359524   symptomatic
# 53         25.224393   symptomatic
# 94         23.486218   symptomatic
# 75         20.201043   symptomatic
# 72         17.781302   symptomatic
# 129      1065.100000  asymptomatic
# 124       710.066667  asymptomatic
# 123       608.628571  asymptomatic
# 119       499.265625  asymptomatic
# 121       473.377778  asymptomatic
# 85        169.063492  asymptomatic
# 87        139.228758  asymptomatic
# 112       119.338936  asymptomatic
# 10         40.575238  asymptomatic
# 106        40.041353  asymptomatic
# 38         39.816822  asymptomatic
# 99         36.918544  asymptomatic
# 76         26.627500  asymptomatic
# 30         26.105392  asymptomatic
# 128        25.914842  asymptomatic
# 54         25.224393  asymptomatic
# 96         24.317352  asymptomatic
# 93         23.486218  asymptomatic
# 74         20.201043  asymptomatic
# 73         17.781302  asymptomatic
# 52         16.417726  asymptomatic
# 49         12.996949  asymptomatic

# %%
list(GO_permod.plot_df["pathway"])
# Out:
# ['Regulation Of Hepatocyte Proliferation (GO:2000345)',
#  'C-terminal Protein Lipidation (GO:0006501)',
#  'Regulation Of Endothelial Cell Differentiation (GO:0045601)',
#  'Sphingomyelin Biosynthetic Process (GO:0006686)',
#  'Complement Activation, Lectin Pathway (GO:0001867)',
#  'Protein Retention In ER Lumen (GO:0006621)',
#  'Telomere Maintenance Via Recombination (GO:0000722)',
#  'Polyol Metabolic Process (GO:0019751)',
#  'snRNA Transcription By RNA Polymerase II (GO:0042795)',
#  'Histone H3-K14 Acetylation (GO:0044154)',
#  'U2-type Prespliceosome Assembly (GO:1903241)',
#  'Ethanol Catabolic Process (GO:0006068)',
#  'Histone H2A Monoubiquitination (GO:0035518)',
#  'Regulation Of Macrophage Proliferation (GO:0120040)',
#  'ISG15-protein Conjugation (GO:0032020)',
#  'Nuclear-Transcribed mRNA Catabolic Process, Deadenylation-Independent Decay (GO:0031086)',
#  'Neutrophil Degranulation (GO:0043312)',
#  'Regulation Of Mitochondrial mRNA Stability (GO:0044528)',
#  'Regulation Of SA Node Cell Action Potential (GO:0098907)',
#  'DNA Replication-Dependent Chromatin Assembly (GO:0006335)',
#  'Parallel Actin Filament Bundle Assembly (GO:0030046)',
#  'Histone H4-K5 Acetylation (GO:0043981)',
#  'Sphingomyelin Biosynthetic Process (GO:0006686)',
#  'Regulation Of T-helper 1 Cell Differentiation (GO:0045625)',
#  'Regulation Of Hepatocyte Proliferation (GO:2000345)',
#  'Regulation Of Endothelial Cell Differentiation (GO:0045601)',
#  'Inclusion Body Assembly (GO:0070841)',
#  'Nucleobase Catabolic Process (GO:0046113)',
#  'Telomere Maintenance Via Recombination (GO:0000722)',
#  'Polyol Metabolic Process (GO:0019751)',
#  'Ethanol Catabolic Process (GO:0006068)',
#  'Histone H2A Monoubiquitination (GO:0035518)',
#  'Regulation Of Macrophage Proliferation (GO:0120040)',
#  'Formation Of Cytoplasmic Translation Initiation Complex (GO:0001732)',
#  'Mitochondrial Proton-Transporting ATP Synthase Complex Assembly (GO:0033615)',
#  'Regulation Of Mitochondrial mRNA Stability (GO:0044528)',
#  'Vesicle-Mediated Transport (GO:0016192)',
#  'Regulation Of SA Node Cell Action Potential (GO:0098907)',
#  'Gap Junction Assembly (GO:0016264)',
#  'DNA Replication-Dependent Chromatin Assembly (GO:0006335)',
#  'Parallel Actin Filament Bundle Assembly (GO:0030046)',
#  'Histone H4-K5 Acetylation (GO:0043981)',
#  'Nuclear-Transcribed mRNA Catabolic Process, Deadenylation-Independent Decay (GO:0031086)',
#  'Neutrophil Degranulation (GO:0043312)']

# %%
# GO doesnt have class info like KEGG. Assign categories manually
go_bp_categories = {
    'Regulation Of Hepatocyte Proliferation (GO:2000345)': 'Developmental and Differentiation Processes',
    'C-terminal Protein Lipidation (GO:0006501)': 'Gene Expression and Regulation',
    'Regulation Of Endothelial Cell Differentiation (GO:0045601)': 'Developmental and Differentiation Processes',
    'Sphingomyelin Biosynthetic Process (GO:0006686)': 'Metabolism and Biosynthesis',
    'Complement Activation, Lectin Pathway (GO:0001867)': 'Immune and Stress Response',
    'Protein Retention In ER Lumen (GO:0006621)': 'Cellular Structure and Transport',
    'Telomere Maintenance Via Recombination (GO:0000722)': 'Gene Expression and Regulation',
    'Polyol Metabolic Process (GO:0019751)': 'Metabolism and Biosynthesis',
    'snRNA Transcription By RNA Polymerase II (GO:0042795)': 'Gene Expression and Regulation',
    'Histone H3-K14 Acetylation (GO:0044154)': 'Gene Expression and Regulation',
    'U2-type Prespliceosome Assembly (GO:1903241)': 'Gene Expression and Regulation',
    'Ethanol Catabolic Process (GO:0006068)': 'Metabolism and Biosynthesis',
    'Histone H2A Monoubiquitination (GO:0035518)': 'Gene Expression and Regulation',
    'Regulation Of Macrophage Proliferation (GO:0120040)': 'Immune and Stress Response',
    'ISG15-protein Conjugation (GO:0032020)': 'Gene Expression and Regulation',
    'Nuclear-Transcribed mRNA Catabolic Process, Deadenylation-Independent Decay (GO:0031086)': 'Gene Expression and Regulation',
    'Neutrophil Degranulation (GO:0043312)': 'Immune and Stress Response',
    'Regulation Of Mitochondrial mRNA Stability (GO:0044528)': 'Gene Expression and Regulation',
    'Regulation Of SA Node Cell Action Potential (GO:0098907)': 'Developmental and Differentiation Processes',
    'DNA Replication-Dependent Chromatin Assembly (GO:0006335)': 'Gene Expression and Regulation',
    'Parallel Actin Filament Bundle Assembly (GO:0030046)': 'Cellular Structure and Transport',
    'Histone H4-K5 Acetylation (GO:0043981)': 'Gene Expression and Regulation',
    'Sphingomyelin Biosynthetic Process (GO:0006686)': 'Metabolism and Biosynthesis',
    'Regulation Of T-helper 1 Cell Differentiation (GO:0045625)': 'Immune and Stress Response',
    'Regulation Of Hepatocyte Proliferation (GO:2000345)': 'Developmental and Differentiation Processes',
    'Regulation Of Endothelial Cell Differentiation (GO:0045601)': 'Developmental and Differentiation Processes',
    'Inclusion Body Assembly (GO:0070841)': 'Cellular Structure and Transport',
    'Nucleobase Catabolic Process (GO:0046113)': 'Metabolism and Biosynthesis',
    'Telomere Maintenance Via Recombination (GO:0000722)': 'Gene Expression and Regulation',
    'Polyol Metabolic Process (GO:0019751)': 'Metabolism and Biosynthesis',
    'Ethanol Catabolic Process (GO:0006068)': 'Metabolism and Biosynthesis',
    'Histone H2A Monoubiquitination (GO:0035518)': 'Gene Expression and Regulation',
    'Regulation Of Macrophage Proliferation (GO:0120040)': 'Immune and Stress Response',
    'Formation Of Cytoplasmic Translation Initiation Complex (GO:0001732)': 'Gene Expression and Regulation',
    'Mitochondrial Proton-Transporting ATP Synthase Complex Assembly (GO:0033615)': 'Metabolism and Biosynthesis',
    'Regulation Of Mitochondrial mRNA Stability (GO:0044528)': 'Gene Expression and Regulation',
    'Vesicle-Mediated Transport (GO:0016192)': 'Cellular Structure and Transport',
    'Regulation Of SA Node Cell Action Potential (GO:0098907)': 'Developmental and Differentiation Processes',
    'Gap Junction Assembly (GO:0016264)': 'Cellular Structure and Transport',
    'DNA Replication-Dependent Chromatin Assembly (GO:0006335)': 'Gene Expression and Regulation',
    'Parallel Actin Filament Bundle Assembly (GO:0030046)': 'Cellular Structure and Transport',
    'Histone H4-K5 Acetylation (GO:0043981)': 'Gene Expression and Regulation',
    'Nuclear-Transcribed mRNA Catabolic Process, Deadenylation-Independent Decay (GO:0031086)': 'Gene Expression and Regulation',
    'Neutrophil Degranulation (GO:0043312)': 'Immune and Stress Response'
}

# %%
GO_permod.plot_df["class"] = GO_permod.plot_df["pathway"].map(go_bp_categories)

# %%
GO_permod.plot_df = encode_cohort(GO_permod.plot_df)
GO_permod.plot_df = format_bubble_df(GO_permod.plot_df)

# %%
GO_permod.plot_df
# Out:
#                                               pathway  cohort_encoded  \
# 0   Regulation Of Hepatocyte Proliferation (GO:200...             1.0
# 1          C-terminal Protein Lipidation (GO:0006501)             1.0
# 2   Regulation Of Endothelial Cell Differentiation...             1.0
# 3     Sphingomyelin Biosynthetic Process (GO:0006686)             1.0
# 4   Complement Activation, Lectin Pathway (GO:0001...             1.0
# 5          Protein Retention In ER Lumen (GO:0006621)             1.0
# 6   Telomere Maintenance Via Recombination (GO:000...             1.0
# 7               Polyol Metabolic Process (GO:0019751)             1.0
# 8   snRNA Transcription By RNA Polymerase II (GO:0...             1.0
# 9             Histone H3-K14 Acetylation (GO:0044154)             1.0
# 10       U2-type Prespliceosome Assembly (GO:1903241)             1.0
# 11             Ethanol Catabolic Process (GO:0006068)             1.0
# 12        Histone H2A Monoubiquitination (GO:0035518)             1.0
# 13  Regulation Of Macrophage Proliferation (GO:012...             1.0
# 14             ISG15-protein Conjugation (GO:0032020)             1.0
# 15  Nuclear-Transcribed mRNA Catabolic Process, De...             1.0
# 16              Neutrophil Degranulation (GO:0043312)             1.0
# 21  1.181973e-17        17.781302               Gene Expression and Regulation
# 22  1.343368e-02      1065.100000                  Metabolism and Biosynthesis
# 23  1.897880e-02       710.066667                   Immune and Stress Response
# 24  2.846111e-02       608.628571  Developmental and Differentiation Processes
# 25  4.575242e-06       499.265625  Developmental and Differentiation Processes
# 26  4.255067e-02       473.377778             Cellular Structure and Transport
# 27  1.225699e-02       169.063492                  Metabolism and Biosynthesis
# 28  7.081041e-05       139.228758               Gene Expression and Regulation
# 29  3.041205e-02       119.338936                  Metabolism and Biosynthesis
# 30  1.379571e-07        40.575238                  Metabolism and Biosynthesis
# 31  3.733331e-02        40.041353               Gene Expression and Regulation
# 32  5.269729e-03        39.816822                   Immune and Stress Response
# 33  1.536813e-20        36.918544               Gene Expression and Regulation
# 34  4.999106e-09        26.627500                  Metabolism and Biosynthesis
# 35  1.215142e-07        26.105392               Gene Expression and Regulation
# 36  4.067849e-02        25.914842             Cellular Structure and Transport
# 37  7.356640e-03        25.224393  Developmental and Differentiation Processes
# 38  8.547004e-05        24.317352             Cellular Structure and Transport
# 39  3.228078e-06        23.486218               Gene Expression and Regulation
# 40  9.824140e-04        20.201043             Cellular Structure and Transport
# 41  1.181973e-17        17.781302               Gene Expression and Regulation
# 42  1.880823e-03        16.417726               Gene Expression and Regulation
# 43  1.016505e-04        12.996949                   Immune and Stress Response
# 44  1.000000e-03         1.000000                                            z
# 45  1.000000e-03         1.000000                                            z

# %%
# Shorten class text for figure
GO_permod.plot_df.loc[GO_permod.plot_df["class"] == "Gene Expression and Regulation", "class"] = "Gene Regulation"
GO_permod.plot_df.loc[GO_permod.plot_df["class"] == "Immune and Stress Response", "class"] = "Immune"
GO_permod.plot_df.loc[GO_permod.plot_df["class"] == "Metabolism and Biosynthesis", "class"] = "Metabolism"
GO_permod.plot_df.loc[GO_permod.plot_df["class"] == "Developmental and Differentiation Processes", "class"] = "Development"
GO_permod.plot_df.loc[GO_permod.plot_df["class"] == "Cellular Structure and Transport", "class"] = "Cell Structure"

#GO_permod.plot_df.loc[GO_permod.plot_df["class"] == "Developmental and Differentiation Processes", "class"] = "Development"
GO_permod.plot_df
# Out:
#                                               pathway  cohort_encoded  \
# 0   Regulation Of Hepatocyte Proliferation (GO:200...             1.0
# 1          C-terminal Protein Lipidation (GO:0006501)             1.0
# 2   Regulation Of Endothelial Cell Differentiation...             1.0
# 3     Sphingomyelin Biosynthetic Process (GO:0006686)             1.0
# 4   Complement Activation, Lectin Pathway (GO:0001...             1.0
# 5          Protein Retention In ER Lumen (GO:0006621)             1.0
# 6   Telomere Maintenance Via Recombination (GO:000...             1.0
# 7               Polyol Metabolic Process (GO:0019751)             1.0
# 8   snRNA Transcription By RNA Polymerase II (GO:0...             1.0
# 9             Histone H3-K14 Acetylation (GO:0044154)             1.0
# 10       U2-type Prespliceosome Assembly (GO:1903241)             1.0
# 11             Ethanol Catabolic Process (GO:0006068)             1.0
# 12        Histone H2A Monoubiquitination (GO:0035518)             1.0
# 21  1.181973e-17        17.781302  Gene Regulation
# 22  1.343368e-02      1065.100000       Metabolism
# 23  1.897880e-02       710.066667           Immune
# 24  2.846111e-02       608.628571      Development
# 25  4.575242e-06       499.265625      Development
# 26  4.255067e-02       473.377778   Cell Structure
# 27  1.225699e-02       169.063492       Metabolism
# 28  7.081041e-05       139.228758  Gene Regulation
# 29  3.041205e-02       119.338936       Metabolism
# 30  1.379571e-07        40.575238       Metabolism
# 31  3.733331e-02        40.041353  Gene Regulation
# 32  5.269729e-03        39.816822           Immune
# 33  1.536813e-20        36.918544  Gene Regulation
# 34  4.999106e-09        26.627500       Metabolism
# 35  1.215142e-07        26.105392  Gene Regulation
# 36  4.067849e-02        25.914842   Cell Structure
# 37  7.356640e-03        25.224393      Development
# 38  8.547004e-05        24.317352   Cell Structure
# 39  3.228078e-06        23.486218  Gene Regulation
# 40  9.824140e-04        20.201043   Cell Structure
# 41  1.181973e-17        17.781302  Gene Regulation
# 42  1.880823e-03        16.417726  Gene Regulation
# 43  1.016505e-04        12.996949           Immune
# 44  1.000000e-03         1.000000                z
# 45  1.000000e-03         1.000000                z

# %%
def format_go_bp_label(go_bp_label):
    new_label = go_bp_label.split("(GO:")[0].rstrip()
    return new_label

# %%
GO_permod.plot_df["pathway"] = GO_permod.plot_df["pathway"].apply(format_go_bp_label)
GO_permod.plot_df
# Out:
#                                               pathway  cohort_encoded  \
# 0              Regulation Of Hepatocyte Proliferation             1.0
# 1                       C-terminal Protein Lipidation             1.0
# 2      Regulation Of Endothelial Cell Differentiation             1.0
# 3                  Sphingomyelin Biosynthetic Process             1.0
# 4               Complement Activation, Lectin Pathway             1.0
# 5                       Protein Retention In ER Lumen             1.0
# 6              Telomere Maintenance Via Recombination             1.0
# 7                            Polyol Metabolic Process             1.0
# 8            snRNA Transcription By RNA Polymerase II             1.0
# 9                          Histone H3-K14 Acetylation             1.0
# 10                    U2-type Prespliceosome Assembly             1.0
# 11                          Ethanol Catabolic Process             1.0
# 12                     Histone H2A Monoubiquitination             1.0
# 13             Regulation Of Macrophage Proliferation             1.0
# 14                          ISG15-protein Conjugation             1.0
# 15  Nuclear-Transcribed mRNA Catabolic Process, De...             1.0
# 16                           Neutrophil Degranulation             1.0
# 17         Regulation Of Mitochondrial mRNA Stability             1.0
# 18        Regulation Of SA Node Cell Action Potential             1.0
# 19       DNA Replication-Dependent Chromatin Assembly             1.0
# 20            Parallel Actin Filament Bundle Assembly             1.0
# 21                          Histone H4-K5 Acetylation             1.0
# 22                 Sphingomyelin Biosynthetic Process             0.0
# 23      Regulation Of T-helper 1 Cell Differentiation             0.0
# 24             Regulation Of Hepatocyte Proliferation             0.0
# 25     Regulation Of Endothelial Cell Differentiation             0.0
# 26                            Inclusion Body Assembly             0.0
# 27                       Nucleobase Catabolic Process             0.0
# 28             Telomere Maintenance Via Recombination             0.0
# 29                           Polyol Metabolic Process             0.0
# 30                          Ethanol Catabolic Process             0.0
# 31                     Histone H2A Monoubiquitination             0.0
