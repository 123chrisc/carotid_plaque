# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from cmcrameri import cm

# %%
## Import full enrichment results
data_dir = r"C:\Users\neil_\DellXPS_June2024\OneDrive\Desktop\New UHN\Precision Medicine\carotid_plaque\workflow\pathway_enrichment\\"
kegg_mirna = pd.read_csv(data_dir+"dem_pathways_kegg.csv")
go_mirna = pd.read_csv(data_dir+"dem_pathways_go.csv")
go_mirna.drop(columns=["pthwy_id"],inplace=True)

# %%
## Import filtered lists (filtered by SR)
data_dir = r"C:\Users\neil_\DellXPS_June2024\OneDrive\Desktop\New UHN\Precision Medicine\carotid_plaque\data\filtered_lists\\"
kegg_top = pd.read_csv(data_dir+"dem_kegg_top.txt", sep="\t", header=None) # NP removed redundant pathways "Longevity regulating pathway - multiple species", "Apoptosis - multiple species"
kegg_ec =  pd.read_csv(data_dir+"dem_kegg_ec.txt", sep="\t", header=None)

go_top = pd.read_csv(data_dir+"dem_go_top.txt", sep="\t", header=None)
go_ec =  pd.read_csv(data_dir+"dem_go_ec.txt", sep="\t", header=None)

# %%
class Enrichment:
    def __init__(self, db, all_df, top_df, ec_df):
        self.database = db
        self.enrichment_df = all_df
        self.top_pathways = list(set(top_df[0]))
        self.endo_pathways = list(set(top_df[0]))

# %%
GO_miRNA = Enrichment("GO BP", go_mirna, go_top, go_ec)
KEGG_miRNA = Enrichment("KEGG", kegg_mirna, kegg_top, kegg_ec)

# %%
def subset_plot_df(plot_df, n=20):
    '''Include the top n (by fold enrichment) pathways for both cohorts in plot_df'''
    pathways_to_plot = set()
    for cohort in ["symptomatic", "asymptomatic"]:
        cohort_df = plot_df[plot_df["cohort"] == cohort]
        cohort_pthwys = cohort_df.sort_values(by="fold_enrichment", ascending=False).head(n)["pathway"]
        pathways_to_plot.update(cohort_pthwys)

    # Filter plot_df to include top n pathways for either cohort
    filtered_df = plot_df[plot_df["pathway"].isin(pathways_to_plot)]

    return filtered_df

# %%
for Enr in [GO_miRNA, KEGG_miRNA]:
    full_df = Enr.enrichment_df
    top_pthwys = Enr.top_pathways
    # Only include pathways specified by SR
    Enr.prebubble_df = full_df[full_df["pathway"].isin(top_pthwys)]
    Enr.plot_df = subset_plot_df(Enr.prebubble_df)

# %%
### KEGG

# %%
from bioservices import *
import time

kg = KEGG()
kg.organism = "hsa" #specify human as organism 


res = kg.list("pathway", organism="hsa")
all_kegg = res.rstrip("\n").split("\n")
all_kegg = [x.rstrip("Homo sapiens (human)") for x in all_kegg]
all_kegg = [x.rstrip("-") for x in all_kegg]
all_kegg = [x.rstrip() for x in all_kegg]
#pathway_dict = {kegg_id: kegg_pthwy for kegg_id, kegg_pthwy in (pathway.split("\t") for pathway in pathways)}

# Initialize an empty dictionary
kegg_id_pthwy_dict = {}

# Iterate over each string in the pathways list
for pathway in all_kegg:
    # Split the string into KEGG ID and KEGG pathway
    kegg_id, kegg_pthwy = pathway.split("\t")
    # Add the KEGG ID and pathway to the dictionary
    kegg_id_pthwy_dict[kegg_pthwy] = kegg_id

# %%
# Check if all KEGG pathways we need to annotate have IDs
cp_kegg_list = list(KEGG_miRNA.plot_df["pathway"])
set(cp_kegg_list).issubset(kegg_id_pthwy_dict.keys())
# Out:
# True

# %%
def get_kegg_class(kegg_pthwy):
    kegg_id = kegg_id_pthwy_dict[kegg_pthwy]
    class_ = (kg.parse(kg.get(kegg_id))["CLASS"]).split("; ") #This will be a list

    class_0 = class_[0] # Take the first level class
    return class_0

KEGG_miRNA.plot_df["class"] = KEGG_miRNA.plot_df["pathway"].apply(get_kegg_class)
# Out:
# C:\Users\neil_\AppData\Local\Temp\ipykernel_32056\2875537558.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KEGG_miRNA.plot_df["class"] = KEGG_miRNA.plot_df["pathway"].apply(get_kegg_class)

# %%
def encode_cohort(plot_df):
    encode_cohort_map = {"asymptomatic":0,
                         "symptomatic":1}
    encoded_df = plot_df.copy()
    encoded_df["cohort"] = encoded_df["cohort"].map(encode_cohort_map)
    encoded_df.rename(columns = {"cohort":"cohort_encoded"}, inplace=True)
    return encoded_df

KEGG_miRNA.plot_df = encode_cohort(KEGG_miRNA.plot_df)
# Out:
#                                               pathway       q-value  \
# 4   AGE-RAGE signaling pathway in diabetic complic...  1.068315e-18
# 9                               p53 signaling pathway  3.870042e-11
# 11                                Cellular senescence  5.984576e-21
# 13                        Prolactin signaling pathway  1.569370e-09
# 16                                         Cell cycle  1.360287e-15
# 20                          Type II diabetes mellitus  6.373188e-06
# 21                             FoxO signaling pathway  1.721645e-14
# 22                             ErbB signaling pathway  7.895223e-10
# 25                              TNF signaling pathway  3.026586e-12
# 27                                          Apoptosis  2.062204e-14
# 30                                  Adherens junction  4.695165e-08
# 31                     Neurotrophin signaling pathway  1.799390e-12
# 38                            HIF-1 signaling pathway  1.276735e-09
# 39                       Longevity regulating pathway  4.635345e-08
# 40                  Thyroid hormone signaling pathway  1.884500e-10
# 41                  T cell receptor signaling pathway  4.155933e-09
# 43                                 Autophagy - animal  2.423941e-11
# 44  Signaling pathways regulating pluripotency of ...  9.602376e-12
# 45                         TGF-beta signaling pathway  4.860669e-08
# 46                             VEGF signaling pathway  2.125580e-05
#
#     fold_enrichment  cohort_encoded                                 class
# 4          3.200126               1                        Human Diseases
# 9          2.862847               1                    Cellular Processes
# 11         2.804925               1                    Cellular Processes
# 13         2.705646               1                    Organismal Systems
# 16         2.686084               1                    Cellular Processes
# 20         2.555558               1                        Human Diseases
# 21         2.542553               1  Environmental Information Processing
# 22         2.535514               1  Environmental Information Processing
# 25         2.507388               1  Environmental Information Processing
# 27         2.497097               1                    Cellular Processes
# 30         2.483570               1                    Cellular Processes
# 31         2.469657               1                    Organismal Systems
# 38         2.276817               1  Environmental Information Processing
# 39         2.274797               1                    Organismal Systems
# 40         2.266914               1                    Organismal Systems
# 41         2.260686               1                    Organismal Systems
# 43         2.240518               1                    Cellular Processes
# 44         2.237851               1                    Cellular Processes
# 45         2.223275               1  Environmental Information Processing
# 46         2.213854               1  Environmental Information Processing

# %%
def format_bubble_df(bubble_df_):
    '''Formats bubble_df by taking the columns needed for plot maker. Also adds rows for wrapping figure'''
    
    #new_df = bubble_df_[["pathway", "cohort_encoded", "q-value", "fold_enrichment"]].copy()
    
    wrap_row1 = pd.DataFrame([{'pathway': 'wrap', 'cohort_encoded': -0.5, 'q-value': 0.001, 'fold_enrichment': 1, 'class':'z'}])
    wrap_row2 = pd.DataFrame([{'pathway': 'wrap', 'cohort_encoded': 1.5, 'q-value': 0.001, 'fold_enrichment': 1, 'class':'z'}])
    
    wrap_rows = pd.concat([wrap_row1, wrap_row2])
    
    formatted_bubble_df = pd.concat([bubble_df_, wrap_rows], ignore_index=True).copy()
    formatted_bubble_df = formatted_bubble_df[["pathway", "cohort_encoded", "q-value", "fold_enrichment", "class"]]
    return formatted_bubble_df

KEGG_miRNA.plot_df = format_bubble_df(KEGG_miRNA.plot_df)
#KEGG_miRNA.plot_df = KEGG_miRNA.plot_df[["pathway", "cohort_encoded", "q-value", "fold_enrichment", "class"]]
KEGG_miRNA.plot_df
# Out:
#                                               pathway  cohort_encoded  \
# 0   AGE-RAGE signaling pathway in diabetic complic...             1.0
# 1                               p53 signaling pathway             1.0
# 2                                 Cellular senescence             1.0
# 3                         Prolactin signaling pathway             1.0
# 4                                          Cell cycle             1.0
# 5                           Type II diabetes mellitus             1.0
# 6                              FoxO signaling pathway             1.0
# 7                              ErbB signaling pathway             1.0
# 8                               TNF signaling pathway             1.0
# 9                                           Apoptosis             1.0
# 10                                  Adherens junction             1.0
# 11                     Neurotrophin signaling pathway             1.0
# 12                            HIF-1 signaling pathway             1.0
# 13                       Longevity regulating pathway             1.0
# 14                  Thyroid hormone signaling pathway             1.0
# 15                  T cell receptor signaling pathway             1.0
# 16                                 Autophagy - animal             1.0
# 17  Signaling pathways regulating pluripotency of ...             1.0
# 18                         TGF-beta signaling pathway             1.0
# 19                             VEGF signaling pathway             1.0
# 20                                               wrap            -0.5
# 21                                               wrap             1.5
#
#          q-value  fold_enrichment                                 class
# 0   1.068315e-18         3.200126                        Human Diseases
# 1   3.870042e-11         2.862847                    Cellular Processes
# 2   5.984576e-21         2.804925                    Cellular Processes
# 3   1.569370e-09         2.705646                    Organismal Systems
# 4   1.360287e-15         2.686084                    Cellular Processes
# 5   6.373188e-06         2.555558                        Human Diseases
# 6   1.721645e-14         2.542553  Environmental Information Processing
# 7   7.895223e-10         2.535514  Environmental Information Processing
# 8   3.026586e-12         2.507388  Environmental Information Processing
# 9   2.062204e-14         2.497097                    Cellular Processes
# 10  4.695165e-08         2.483570                    Cellular Processes
# 11  1.799390e-12         2.469657                    Organismal Systems
# 12  1.276735e-09         2.276817  Environmental Information Processing
# 13  4.635345e-08         2.274797                    Organismal Systems
# 14  1.884500e-10         2.266914                    Organismal Systems
# 15  4.155933e-09         2.260686                    Organismal Systems
# 16  2.423941e-11         2.240518                    Cellular Processes
# 17  9.602376e-12         2.237851                    Cellular Processes
# 18  4.860669e-08         2.223275  Environmental Information Processing
# 19  2.125580e-05         2.213854  Environmental Information Processing
# 20  1.000000e-03         1.000000                                     z
# 21  1.000000e-03         1.000000                                     z

# %%
# Shorten class text for figure
KEGG_miRNA.plot_df.loc[KEGG_miRNA.plot_df["class"] == "Environmental Information Processing", "class"] = "Env. Info. Processing"
KEGG_miRNA.plot_df.loc[KEGG_miRNA.plot_df["class"] == "Human Diseases", "class"] = "Diseases"
KEGG_miRNA.plot_df
# Out:
#                                               pathway  cohort_encoded  \
# 0   AGE-RAGE signaling pathway in diabetic complic...             1.0
# 1                               p53 signaling pathway             1.0
# 2                                 Cellular senescence             1.0
# 3                         Prolactin signaling pathway             1.0
# 4                                          Cell cycle             1.0
# 5                           Type II diabetes mellitus             1.0
# 6                              FoxO signaling pathway             1.0
# 7                              ErbB signaling pathway             1.0
# 8                               TNF signaling pathway             1.0
# 9                                           Apoptosis             1.0
# 10                                  Adherens junction             1.0
# 11                     Neurotrophin signaling pathway             1.0
# 12                            HIF-1 signaling pathway             1.0
# 13                       Longevity regulating pathway             1.0
# 14                  Thyroid hormone signaling pathway             1.0
# 15                  T cell receptor signaling pathway             1.0
# 16                                 Autophagy - animal             1.0
# 17  Signaling pathways regulating pluripotency of ...             1.0
# 18                         TGF-beta signaling pathway             1.0
# 19                             VEGF signaling pathway             1.0
# 20                                               wrap            -0.5
# 21                                               wrap             1.5
#
#          q-value  fold_enrichment                  class
# 0   1.068315e-18         3.200126               Diseases
# 1   3.870042e-11         2.862847     Cellular Processes
# 2   5.984576e-21         2.804925     Cellular Processes
# 3   1.569370e-09         2.705646     Organismal Systems
# 4   1.360287e-15         2.686084     Cellular Processes
# 5   6.373188e-06         2.555558               Diseases
# 6   1.721645e-14         2.542553  Env. Info. Processing
# 7   7.895223e-10         2.535514  Env. Info. Processing
# 8   3.026586e-12         2.507388  Env. Info. Processing
# 9   2.062204e-14         2.497097     Cellular Processes
# 10  4.695165e-08         2.483570     Cellular Processes
# 11  1.799390e-12         2.469657     Organismal Systems
# 12  1.276735e-09         2.276817  Env. Info. Processing
# 13  4.635345e-08         2.274797     Organismal Systems
# 14  1.884500e-10         2.266914     Organismal Systems
# 15  4.155933e-09         2.260686     Organismal Systems
# 16  2.423941e-11         2.240518     Cellular Processes
# 17  9.602376e-12         2.237851     Cellular Processes
# 18  4.860669e-08         2.223275  Env. Info. Processing
# 19  2.125580e-05         2.213854  Env. Info. Processing
# 20  1.000000e-03         1.000000                      z
# 21  1.000000e-03         1.000000                      z

# %%
KEGG_miRNA.plot_df.to_csv('dem_kegg_bubble.txt', sep ='\t',index=False)

# %% [markdown]
# ## GO

# %%
GO_miRNA.plot_df
# Out:
#                                                pathway  fold_enrichment  \
# 0                         cochlear nucleus development         9.996117
# 4                           sphingolipid translocation         9.996117
# 5            regulation of mast cell apoptotic process         9.996117
# 10                         fungiform papilla formation         9.996117
# 11                          osteoblast fate commitment         9.996117
# 12   regulation of cell proliferation involved in h...         9.996117
# 14   apoptotic process involved in embryonic digit ...         9.996117
# 15   intrinsic apoptotic signaling pathway in respo...         9.996117
# 17                central nervous system morphogenesis         9.996117
# 18              regulation of primary miRNA processing         8.330097
# 19               cytoplasmic sequestering of NF-kappaB         8.330097
# 20                  maintenance of DNA repeat elements         8.330097
# 21   regulation of protein localization to endoplas...         7.996893
# 22   regulation of termination of DNA-templated tra...         7.996893
# 23                        cranial ganglion development         7.996893
# 24                        glial cell apoptotic process         7.996893
# 25                     hair follicle placode formation         7.996893
# 26                     fungiform papilla morphogenesis         7.996893
# 28         regulation of metalloendopeptidase activity         7.996893
# 43                regulation of ureteric bud formation         7.497087
# 97       regulation of epithelial cell differentiation         6.359236
# 939      regulation of epithelial cell differentiation         2.737790
#
#           q-value        cohort
# 0    8.949369e-03   symptomatic
# 4    8.902322e-03   symptomatic
# 5    8.928398e-03   symptomatic
# 10   8.881571e-03   symptomatic
# 11   8.933632e-03   symptomatic
# 12   8.876398e-03   symptomatic
# 14   8.938871e-03   symptomatic
# 15   8.917950e-03   symptomatic
# 17   8.944117e-03   symptomatic
# 18   7.402361e-04   symptomatic
# 19   7.408918e-04   symptomatic
# 20   7.395816e-04   symptomatic
# 21   4.676312e-03   symptomatic
# 22   4.670077e-03   symptomatic
# 23   4.663859e-03   symptomatic
# 24   4.654562e-03   symptomatic
# 25   4.660755e-03   symptomatic
# 26   4.657657e-03   symptomatic
# 28   4.666966e-03   symptomatic
# 43   2.725717e-02   symptomatic
# 97   3.036432e-02  asymptomatic
# 939  1.648314e-08   symptomatic

# %%
# GO doesnt have class info like KEGG. Assign categories manually
go_bp_categories = {
    'cochlear nucleus development': 'Developmental Processes',
    'sphingolipid translocation': 'Metabolism and Transport',
    'regulation of mast cell apoptotic process': 'Immune and Apoptotic Processes',
    'fungiform papilla formation': 'Developmental Processes',
    'osteoblast fate commitment': 'Developmental Processes',
    'regulation of cell proliferation involved in heart valve morphogenesis': 'Developmental Processes',
    'apoptotic process involved in embryonic digit morphogenesis': 'Immune and Apoptotic Processes',
    'intrinsic apoptotic signaling pathway in response to hypoxia': 'Immune and Apoptotic Processes',
    'central nervous system morphogenesis': 'Developmental Processes',
    'regulation of primary miRNA processing': 'Gene Expression and Regulation',
    'cytoplasmic sequestering of NF-kappaB': 'Gene Expression and Regulation',
    'maintenance of DNA repeat elements': 'Gene Expression and Regulation',
    'regulation of protein localization to endoplasmic reticulum': 'Metabolism and Transport',
    'regulation of termination of DNA-templated transcription': 'Gene Expression and Regulation',
    'cranial ganglion development': 'Developmental Processes',
    'glial cell apoptotic process': 'Immune and Apoptotic Processes',
    'hair follicle placode formation': 'Developmental Processes',
    'fungiform papilla morphogenesis': 'Developmental Processes',
    'regulation of metalloendopeptidase activity': 'Metabolism and Transport',
    'regulation of ureteric bud formation': 'Developmental Processes',
    'regulation of epithelial cell differentiation': 'Developmental Processes'
}

# %%
GO_miRNA.plot_df["class"] = GO_miRNA.plot_df["pathway"].map(go_bp_categories)
# Out:
# C:\Users\neil_\AppData\Local\Temp\ipykernel_32056\1521061464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GO_miRNA.plot_df["class"] = GO_miRNA.plot_df["pathway"].map(go_bp_categories)

# %%
GO_miRNA.plot_df = encode_cohort(GO_miRNA.plot_df)
GO_miRNA.plot_df = format_bubble_df(GO_miRNA.plot_df)
# Out:
#                                               pathway  cohort_encoded  \
# 0                        cochlear nucleus development             1.0
# 1                          sphingolipid translocation             1.0
# 2           regulation of mast cell apoptotic process             1.0
# 3                         fungiform papilla formation             1.0
# 4                          osteoblast fate commitment             1.0
# 5   regulation of cell proliferation involved in h...             1.0
# 6   apoptotic process involved in embryonic digit ...             1.0
# 7   intrinsic apoptotic signaling pathway in respo...             1.0
# 8                central nervous system morphogenesis             1.0
# 9              regulation of primary miRNA processing             1.0
# 10              cytoplasmic sequestering of NF-kappaB             1.0
# 11                 maintenance of DNA repeat elements             1.0
# 12  regulation of protein localization to endoplas...             1.0
# 13  regulation of termination of DNA-templated tra...             1.0
# 14                       cranial ganglion development             1.0
# 15                       glial cell apoptotic process             1.0
# 16                    hair follicle placode formation             1.0
# 17                    fungiform papilla morphogenesis             1.0
# 18        regulation of metalloendopeptidase activity             1.0
# 19               regulation of ureteric bud formation             1.0
# 20      regulation of epithelial cell differentiation             0.0
# 21      regulation of epithelial cell differentiation             1.0
# 22                                               wrap            -0.5
# 23                                               wrap             1.5
#
#          q-value  fold_enrichment                           class
# 0   8.949369e-03         9.996117         Developmental Processes
# 1   8.902322e-03         9.996117        Metabolism and Transport
# 2   8.928398e-03         9.996117  Immune and Apoptotic Processes
# 3   8.881571e-03         9.996117         Developmental Processes
# 4   8.933632e-03         9.996117         Developmental Processes
# 5   8.876398e-03         9.996117         Developmental Processes
# 6   8.938871e-03         9.996117  Immune and Apoptotic Processes
# 7   8.917950e-03         9.996117  Immune and Apoptotic Processes
# 8   8.944117e-03         9.996117         Developmental Processes
# 9   7.402361e-04         8.330097  Gene Expression and Regulation
# 10  7.408918e-04         8.330097  Gene Expression and Regulation
# 11  7.395816e-04         8.330097  Gene Expression and Regulation
# 12  4.676312e-03         7.996893        Metabolism and Transport
# 13  4.670077e-03         7.996893  Gene Expression and Regulation
# 14  4.663859e-03         7.996893         Developmental Processes
# 15  4.654562e-03         7.996893  Immune and Apoptotic Processes
# 16  4.660755e-03         7.996893         Developmental Processes
# 17  4.657657e-03         7.996893         Developmental Processes
# 18  4.666966e-03         7.996893        Metabolism and Transport
# 19  2.725717e-02         7.497087         Developmental Processes
# 20  3.036432e-02         6.359236         Developmental Processes
# 21  1.648314e-08         2.737790         Developmental Processes
# 22  1.000000e-03         1.000000                               z
# 23  1.000000e-03         1.000000                               z

# %%
# Shorten class text for figure
GO_miRNA.plot_df.loc[GO_miRNA.plot_df["class"] == "Gene Expression and Regulation", "class"] = "Gene Regulation"
GO_miRNA.plot_df.loc[GO_miRNA.plot_df["class"] == "Immune and Apoptotic Processes", "class"] = "Immune and Apoptosis"
GO_miRNA.plot_df.loc[GO_miRNA.plot_df["class"] == "Metabolism and Transport", "class"] = "Metabolism"
GO_miRNA.plot_df
# Out:
#                                               pathway  cohort_encoded  \
# 0                        cochlear nucleus development             1.0
# 1                          sphingolipid translocation             1.0
# 2           regulation of mast cell apoptotic process             1.0
# 3                         fungiform papilla formation             1.0
# 4                          osteoblast fate commitment             1.0
# 5   regulation of cell proliferation involved in h...             1.0
# 6   apoptotic process involved in embryonic digit ...             1.0
# 7   intrinsic apoptotic signaling pathway in respo...             1.0
# 8                central nervous system morphogenesis             1.0
# 9              regulation of primary miRNA processing             1.0
# 10              cytoplasmic sequestering of NF-kappaB             1.0
# 11                 maintenance of DNA repeat elements             1.0
# 12  regulation of protein localization to endoplas...             1.0
# 13  regulation of termination of DNA-templated tra...             1.0
# 14                       cranial ganglion development             1.0
# 15                       glial cell apoptotic process             1.0
# 16                    hair follicle placode formation             1.0
# 17                    fungiform papilla morphogenesis             1.0
# 18        regulation of metalloendopeptidase activity             1.0
# 19               regulation of ureteric bud formation             1.0
# 20      regulation of epithelial cell differentiation             0.0
# 21      regulation of epithelial cell differentiation             1.0
# 22                                               wrap            -0.5
# 23                                               wrap             1.5
#
#          q-value  fold_enrichment                    class
# 0   8.949369e-03         9.996117  Developmental Processes
# 1   8.902322e-03         9.996117               Metabolism
# 2   8.928398e-03         9.996117     Immune and Apoptosis
# 3   8.881571e-03         9.996117  Developmental Processes
# 4   8.933632e-03         9.996117  Developmental Processes
# 5   8.876398e-03         9.996117  Developmental Processes
# 6   8.938871e-03         9.996117     Immune and Apoptosis
# 7   8.917950e-03         9.996117     Immune and Apoptosis
# 8   8.944117e-03         9.996117  Developmental Processes
# 9   7.402361e-04         8.330097          Gene Regulation
# 10  7.408918e-04         8.330097          Gene Regulation
# 11  7.395816e-04         8.330097          Gene Regulation
# 12  4.676312e-03         7.996893               Metabolism
# 13  4.670077e-03         7.996893          Gene Regulation
# 14  4.663859e-03         7.996893  Developmental Processes
# 15  4.654562e-03         7.996893     Immune and Apoptosis
# 16  4.660755e-03         7.996893  Developmental Processes
# 17  4.657657e-03         7.996893  Developmental Processes
# 18  4.666966e-03         7.996893               Metabolism
# 19  2.725717e-02         7.497087  Developmental Processes
# 20  3.036432e-02         6.359236  Developmental Processes
# 21  1.648314e-08         2.737790  Developmental Processes
# 22  1.000000e-03         1.000000                        z
# 23  1.000000e-03         1.000000                        z

# %%
GO_miRNA.plot_df.to_csv('dem_go_bubble.txt', sep ='\t',index=False)
